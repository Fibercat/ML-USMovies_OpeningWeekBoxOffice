# %% [markdown]
# # 使用Google APIs - YouTube Data API v3 取得電影預告片留言內容

# %%
import pandas as pd
import googleapiclient.discovery
import datetime

# %% [markdown]
# #### api_keys：可更改api_keys中的金鑰內容

# %%
api_keys = ["AIzaSyA2lO3oKFkCiEb84LxMssuPUBD15S1xcok"]
key_number = 0
current_key = api_keys[key_number]
current_key
# Out:
# 'AIzaSyA2lO3oKFkCiEb84LxMssuPUBD15S1xcok'

# %% [markdown]
# #### change_key(): 當目前使用API key每日流量超出限制時，改變使用的金鑰

# %%
def change_key():
    global api_keys
    global key_number
    global current_key
    global youtube
    if key_number == (len(api_keys)-1):
        print("no more api_keys")
    else:
        key_number += 1
        current_key = api_keys[key_number]
        youtube = googleapiclient.discovery.build("youtube", "v3", developerKey = current_key)
        print("change API Key to:{}".format(current_key))

# %% [markdown]
# #### get_comments(response): 抓取影片所有留言(commentThreads)內容所需的值
# - 影片ID(videoId)
# - 留言時間(publishedAt)
# - 留言者名稱(authorDisplayName)
# - 留言內容(textOriginal)
# - 留言按讚數(likeCount)
# - 留言回覆數(commentsReplyCount)

# %%
def get_comments(response):
    videoId, authorDisplayName, textOriginal, likeCount, publishedAt, totalReplyCount = [],[],[],[],[],[]
    
    for item in response["items"]:
        if  item["kind"] == "youtube#commentThread":
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            videoId.append(snippet["videoId"])
            authorDisplayName.append(snippet["authorDisplayName"])
            textOriginal.append(snippet["textOriginal"])
            likeCount.append(snippet["likeCount"])
            publishedAt.append(snippet["publishedAt"])
            totalReplyCount.append(item["snippet"]["totalReplyCount"])
    
    if len(videoId) == len(authorDisplayName) == len(textOriginal) == len(likeCount) == len(publishedAt) == len(totalReplyCount):
        comments = {'videoid': videoId,
                    'publishedAt': publishedAt,
                    'authorDisplayName': authorDisplayName,
                    'textOriginal': textOriginal,
                    'likeCount': likeCount,
                    'commentsReplyCount': totalReplyCount }
    df_comments = pd.DataFrame(comments)
    return df_comments

# %% [markdown]
# #### get_trailer_comments(videoId): 傳入影片ID(videoId)會取得所抓取的所有評論的內容
# - API限定每一次request只能100筆，換頁要帶nextPageToken參數給下次request使用
# - trailer_comments：儲存評論內容，設為全域變數，有exception發生之前抓取的資料還在裡面！可以先匯出成csv檔存檔！
# - execution_log：是儲存執行與exception發生的資訊

# %%
def get_trailer_comments(videoId):
    global trailer_comments
    global execution_log
    nextPageToken = ""
    page = 0
    while nextPageToken is not None:
        page += 1
        request = youtube.commentThreads().list(videoId=videoId, pageToken=nextPageToken, part="snippet",
                                                maxResults=100, order="time", moderationStatus="published")
        try:
            response = request.execute()
            nextPageToken = response.get('nextPageToken')
            if len(response["items"]) != 0:
                tmp = get_comments(response)
                trailer_comments = pd.concat([trailer_comments, tmp], ignore_index = True)
                execution_log = execution_log.append(
                    pd.DataFrame({'videoid':[videoId],'page':[page],'nextPageToken':[nextPageToken],
                                  'message':["success append!"]}),ignore_index = True)
            else:
                execution_log = execution_log.append(
                    pd.DataFrame({'videoid':[videoId],'page':[page],'nextPageToken':[nextPageToken],
                                  'message':["No available comments"]}), ignore_index = True)
        except Exception as e1:
            execution_log = execution_log.append(
                pd.DataFrame({'videoid':[videoId],'page':[page],'nextPageToken':[nextPageToken],
                              'message':[str(e1)]}), ignore_index = True)
            global flag
            if "Daily Limit Exceeded" in str(e1):
                print("Daily Limit Exceeded!")
                global current_key
                global api_keys
                if current_key == api_keys[-1]:
                    execution_log = execution_log.append(
                        pd.DataFrame({'videoid':[videoId],'page':[page],'nextPageToken':[nextPageToken],
                                      'message':["all API Keys used"]}), ignore_index = True)
                    print("No more API keys...QAQ...")
                    break
                change_key()
            elif "parameter has disabled comments" in str(e1):
                print("Video comments disabled!")
                break
            elif "parameter could not be found" in str(e1):
                print("Video link is invalid!")
                break
            elif "not found and cannot be used for API calls" in str(e1):
                print("API key didn't be activated!...QAQ...")
                flag = False
                break
            elif "API server failed to successfully process the request" in str(e1):
                print("processingFailure by API server...QAQ...")
                flag = False
            else:
                print("unknown error...QAQ...")
                print(str(e1))
                flag = False
                break

# %% [markdown]
# ### 設定連YouTube API所使用的金鑰

# %%
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey = current_key)
current_key
# Out:
# 'AIzaSyA2lO3oKFkCiEb84LxMssuPUBD15S1xcok'

# %% [markdown]
# #### 對照youtube id檔案

# %%
df_trailer = pd.read_csv('D:/Movie/MovieList/trailer_data_with_year.csv', encoding='UTF-8', index_col=0)
df_trailer.head()
# Out:
#    title_id   youtube_id release_time  release_year
# 0     19995  5PSNL1qE6VY     9-Nov-09          2009
# 1      8373  uH3STHC63hU     1-May-09          2009
# 2       767  JYLdTuL9Wjw    12-Jun-09          2009
# 3       767  Jrx8zZveyVU     8-Oct-17          2017
# 4       767  lcNtt0f6KdM     8-Oct-17          2017

# %% [markdown]
# year位置設定各自負責年份，篩選所需年份

# %%
year = 2019
df_trailer = df_trailer[df_trailer['release_year']==year].reset_index(drop=True)
df_trailer.head()
# Out:
#    title_id   youtube_id release_time  release_year
# 0     19585  AD_fezWiaZ0     8-Feb-19          2019
# 1     10138  LebmJcJX3Ck    10-Jun-19          2019
# 2     10138  qMObsIYkqxU    10-Jun-19          2019
# 3     10138  uLUqN8YG-s4    10-Jun-19          2019
# 4     26022  nGH2mTu7AhU    24-Jan-19          2019

# %%
len(df_trailer)
# Out:
# 357

# %%
len(df_trailer[ (df_trailer['youtube_id'] != 'TcMBFSGVi1c') & (df_trailer['youtube_id'] != 'AMSITikqKiM')])
# Out:
# 355

# %%
df_trailer = df_trailer[ (df_trailer['youtube_id'] != 'TcMBFSGVi1c') & (df_trailer['youtube_id'] != 'AMSITikqKiM')].reset_index(drop=True)

# %%
df_trailer.tail()
# Out:
#      title_id   youtube_id release_time  release_year
# 350    555295  pXww9NuqUDU    18-Mar-19          2019
# 351    595985  u61ymqblUU0     5-Jun-19          2019
# 352    595985  XKev4lpHMcE     5-Jun-19          2019
# 353    480429  4MD16iUK4CQ    31-Jan-19          2019
# 354    515676  LaNUEShKr6c    18-Jan-19          2019

# %% [markdown]
# #### 建立trailer_comments與execution_log，寫入csv檔案後記得再執行清空，不然內容會重複寫入

# %%
trailer_comments = pd.DataFrame()
execution_log = pd.DataFrame()

# %%
flag = True

# %% [markdown]
# #### 設定抓取youtube id的起始資料列(start)與結束資料列(end)

# %%
start = 200
end = 355

# %% [markdown]
# ### 執行主程式，Good Luck!

# %% [markdown]
# 若出現 <b>QAQ error</b> 表示可能API Key有問題或是其他不知名錯誤，for迴圈會停止，<b>請注意已抓資料以及對錯誤訊息進行處理</b>

# %%
# %%time
for query_videoId in df_trailer['youtube_id'][start:end]:
    if flag:
        get_trailer_comments(query_videoId)
    else:
        print(f'QAQ error! Current key= {current_key}')
        break
# Out:
# Video comments disabled!
# Video comments disabled!
# Video link is invalid!
# Video comments disabled!
# Wall time: 5min 18s

# %% [markdown]
# ### 檢查執行後成果

# %% [markdown]
# 看每一輪最後一筆video_id, 若與execution_log最後一筆id相同代表抓取成功。<br>
# 若出現QAQ error，建議下次抓取時從上次最後一筆開始抓，檢查是否有抓完整。

# %%
execution_log.tail()
# Out:
#          videoid  page                                      nextPageToken  \
# 553  u61ymqblUU0     4  QURTSl9pMVcySVBfeGtweFJGdzFmdG1WN09qNmVZdHVtZ1...
# 554  u61ymqblUU0     5                                               None
# 555  XKev4lpHMcE     1                                               None
# 556  4MD16iUK4CQ     1                                               None
# 557  LaNUEShKr6c     1                                               None
#
#              message
# 553  success append!
# 554  success append!
# 555  success append!
# 556  success append!
# 557  success append!

# %%
df_trailer['youtube_id'][end-1]
# Out:
# 'LaNUEShKr6c'

# %% [markdown]
# 檢查trailer_comments(抓取的評論筆數), execution_log(執行次數)

# %%
len(trailer_comments), len(execution_log)
# Out:
# (43698, 558)

# %% [markdown]
# 檢查已執行過那些video_id

# %%
execution_log['videoid'].value_counts()
# Out:
# xMJNm24n4Ok    206
# aejAkKGiimk     44
# cQFFnUg0u70     36
# EXNP731K1qE     24
# M7zrHiqoJ6k     19
# 7afc9gTbVFI     18
# i0gTo-qpxSI      7
# 0QzILYONVT0      7
# w47IJjuEV8o      6
# p4m7wgSiDhM      5
# B5HI4VsXvIQ      5
# u61ymqblUU0      5
# Kas0BKHZwEQ      5
# pkaTGGwwvSI      4
# VDlQQD2354A      4
# DovnHrIwfTY      4
# BxY2vnJiByw      4
# hzrFqZcosI0      3
# HIMO1IheTpA      3
# NYCTxoXx-H8      3
# UDaYckxMgpM      2
# GjEPOMZ6sf0      2
# se9n853lBNo      2
# FjfUPLEKZtI      2
# PMlHDNdLGU8      2
# OitVw2gE6aQ      2
# FhyaYaK9lC4      2
# WVZBNT0Ap-A      2
# dmtfpB6MUi0      2
# KPSKkxTQFEU      2
#               ...
# 72mPcb_nLq0      1
# gYko3cN_KZk      1
# l-MzHGRVG4k      1
# oB8PpdeSXRQ      1
# l43skoy-_qw      1
# dPGwJmSMoPs      1
# JsNBLkO2Itg      1
# 3x0aZS6uY7E      1
# dlxYlvNlj8o      1
# 3_yobkhvzJk      1
# ejZ75QFesgE      1
# BLqAGR8eFt8      1
# XKev4lpHMcE      1
# xOKfu8X48Hs      1
# z1JICa6kiOQ      1
# A3NebXesuFc      1
# BrDNYXW9a_Y      1
# UsFGeBRn5SI      1
# QwG3b6e1ARU      1
# sBQF9t1qKkA      1
# 63vgOHam-kg      1
# ljz7WxgTpx0      1
# WmBIY5N5EwU      1
# LByUBimVyJA      1
# 7Oz9pgE7F4o      1
# RztLsnobKzE      1
# A6DVFhvs0AM      1
# NmNT2emdUGY      1
# nl1zpjGkxvs      1
# ydoaqi2Whkk      1
# Name: videoid, Length: 155, dtype: int64

# %% [markdown]
# 檢查已執行過video_id的數量

# %%
execution_log['videoid'].value_counts().count()
# Out:
# 155

# %% [markdown]
# 檢查每筆video_id留言數量

# %%
trailer_comments['videoid'].value_counts()
# Out:
# xMJNm24n4Ok    20513
# aejAkKGiimk     4388
# cQFFnUg0u70     3593
# EXNP731K1qE     2330
# M7zrHiqoJ6k     1888
# 7afc9gTbVFI     1756
# i0gTo-qpxSI      669
# 0QzILYONVT0      643
# w47IJjuEV8o      508
# p4m7wgSiDhM      471
# B5HI4VsXvIQ      457
# u61ymqblUU0      420
# Kas0BKHZwEQ      402
# pkaTGGwwvSI      363
# VDlQQD2354A      332
# DovnHrIwfTY      322
# BxY2vnJiByw      306
# NYCTxoXx-H8      289
# HIMO1IheTpA      270
# hzrFqZcosI0      259
# KPSKkxTQFEU      199
# xxLBTRcDVfU      194
# dmtfpB6MUi0      165
# se9n853lBNo      143
# OitVw2gE6aQ      134
# UDaYckxMgpM      134
# FjfUPLEKZtI      125
# WVZBNT0Ap-A      124
# FhyaYaK9lC4      112
# PMlHDNdLGU8      104
#                ...
# fh9dImdUYIY        6
# sBQF9t1qKkA        5
# OPUZKqaWQAg        4
# 8XdDTM2zcNE        4
# qqCw6DqGbKA        4
# ydoaqi2Whkk        3
# l43skoy-_qw        3
# Fk1iGpUFcjY        3
# NmNT2emdUGY        3
# LByUBimVyJA        3
# LaNUEShKr6c        3
# JsNBLkO2Itg        2
# qVcn6cQ6VeM        2
# 72mPcb_nLq0        2
# A6DVFhvs0AM        2
# UHNEtSJIep0        2
# XMoo2SjBRug        2
# yvSlk7naJFU        1
# bHzfPqwA9x8        1
# GD4rT3GDlEI        1
# 7Oz9pgE7F4o        1
# aKxwgbGasFU        1
# rdfyd4xVd64        1
# UsFGeBRn5SI        1
# z1JICa6kiOQ        1
# G693xPXBwMY        1
# W_m0UIYVhSA        1
# xLrYXoeanxQ        1
# UK3dhXJlFf0        1
# A3NebXesuFc        1
# Name: videoid, Length: 130, dtype: int64

# %% [markdown]
# 檢查有評論的影片數量

# %%
trailer_comments['videoid'].value_counts().count()
# Out:
# 130

# %% [markdown]
# ##### 檢查QAQ error原因與需要重抓的nextPageToken

# %%
df_trailer[df_trailer['youtube_id'] == '3On0BXzGnuI']
# Out:
#      title_id   youtube_id release_time  release_year
# 134    508791  3On0BXzGnuI     6-Feb-19          2019

# %%
df_trailer[134:136]
# Out:
#      title_id   youtube_id release_time  release_year
# 134    508791  3On0BXzGnuI     6-Feb-19          2019
# 135    611291  AwrClxIhsYc     3-Jul-19          2019

# %%
execution_log[execution_log['message'].str.contains('HttpError', regex=False)]
# Out:
#          videoid  page                                      nextPageToken  \
# 77   Ap0NRJD-2ts     1
# 78        #NAME?     1
# 139  3On0BXzGnuI    41  QURTSl9pM3NkbHI5WXF2UnZPTWlvUGJJTXVuZG1zak4wb3...
#
#                                                message
# 77   <HttpError 403 when requesting https://www.goo...
# 78   <HttpError 404 when requesting https://www.goo...
# 139  <HttpError 400 when requesting https://www.goo...

# %%
execution_log.iloc[138].nextPageToken
# Out:
# 'QURTSl9pM3NkbHI5WXF2UnZPTWlvUGJJTXVuZG1zak4wb3I0TkJreHE3SmZkMnI2UjI3VWFPZnVMQUJpM3VCMUVEV1U0RWlRZnI5UXF0UVp0alFQY0QzaDVlVm81cjJZNDdFQ1RYd3dVVHBKZG8zakxZRmphWTJJM2lzWWZlWlo1Ym9SMkdkMWJoTm1JcEduLVE='

# %%
current_key
# Out:
# 'AIzaSyDJSwg-6x_Ytukfh4tK90BCS9fCHwk8404'

# %%
change_key()
# Out:
# change API Key to:AIzaSyD3v6ml3YZpIPxz5EdLSyZMHR068YGdQMM

# %% [markdown]
# ### 將抓取的資料與執行log檔匯出成csv：檔名後自動帶入目前執行日期時間

# %%
trailer_comments.to_csv('trailerComments_{:%Y%m%d_%H%M}.csv'.format(datetime.datetime.now()), encoding="utf-8", index=False)
execution_log.to_csv('executionLog_{:%Y%m%d_%H%M}.csv'.format(datetime.datetime.now()), encoding="utf-8", index=False)

# %%
execution_log
# Out:
#          videoid  page                                      nextPageToken  \
# 0    AD_fezWiaZ0     1                                               None
# 1    LebmJcJX3Ck     1                                               None
# 2    qMObsIYkqxU     1                                               None
# 3    uLUqN8YG-s4     1                                               None
# 4    nGH2mTu7AhU     1                                               None
# 5    7TavVZMewpY     1  QURTSl9pMWVqTjBQZjU3dm5EcVpuaWFIYzhyQkhPdFNPZl...
# 6    7TavVZMewpY     2  QURTSl9pMDJkZExWRi13Sy14WDVFQkVZT0RiR0tyRkU3Zl...
# 7    7TavVZMewpY     3  QURTSl9pMWt4Z1dEOThJRTRSMkNjYVdmOE1OYVY1SFo3bW...
# 8    7TavVZMewpY     4  QURTSl9pMTNCQWpPNlVsMUlOY1E5S3VKQVBYRmZncnd0Y1...
# 9    7TavVZMewpY     5  QURTSl9pMS1jU3RfN1dMb3BrN05MRl9JZmNHbGw0MXdDb0...
# 10   7TavVZMewpY     6  QURTSl9pMUlFcnFMQWlBeDMzMk1CdVBoN2ZGZldBbEtxdU...
# 11   7TavVZMewpY     7  QURTSl9pMDFmejM0R21hYlY5WmRwaTh1eUVUWkVxLWNOZV...
# 12   7TavVZMewpY     8  QURTSl9pMUZHN0d1ZXZQQlNfWlM4MXMxRnJodGVWMWY5ek...
# 387  7TavVZMewpY   383  QURTSl9pM2VUNExEaWJrNFhhN3QyRzFrdjk0aGg1SmlGZF...
# 388  7TavVZMewpY   384  QURTSl9pMGF1RDlHdWJvSkZSU0xKc0x2Slk1WTh6SnhBM2...
# 389  7TavVZMewpY   385  QURTSl9pMkpQcEFHRVJrR2F1a2RBUXQ0SXBCN2owNFB1Yj...
# 390  7TavVZMewpY   386  QURTSl9pMmVPUndJQ3lXamdITGM5V0lJSUNhNjZpVTlHNn...
# 391  7TavVZMewpY   387  QURTSl9pMHF0cVVLY3NDM21QVjZPRGpLNzUyaHZKTFFxMG...
# 392  7TavVZMewpY   388  QURTSl9pMXBDVVZ4Y2FNU2pxOVk1RkQ3X0ZmbkdlRmtaVU...
# 393  7TavVZMewpY   389  QURTSl9pMm5UdXpuWkhRcnNmQWRJd1ZWdGxaODRpSW5VNn...
# 394  7TavVZMewpY   390  QURTSl9pMFlzNDNSVFFHQVVpY3JmeEFibDRsWjEwdmdEOX...
# 395  7TavVZMewpY   391  QURTSl9pMWRPeG5wWjI5SXNTUHpYb0c0YTNKNHBtYmhNS3...
# 396  7TavVZMewpY   392  QURTSl9pMFdjejAzUy1pSkotUkczWFlHcXRITXNPbHgwTX...
# 397  7TavVZMewpY   393  QURTSl9pMFBOTEdCYWIxdl95NWFUcndXd2xmV3BSejM1az...
# 398  7TavVZMewpY   394  QURTSl9pMDZiUmdYTlNZRjRqTlFnTV9CdkpuZXNvdDFlMV...
# 399  7TavVZMewpY   395  QURTSl9pMkc4ckhBZGZGQ1k1VFhNelg3QlBlMmRxbDIybk...
# 400  7TavVZMewpY   396  QURTSl9pMXh3RDFLZVBTbU91WmlicVhCcVpsaXk2WWphLV...
# 401  7TavVZMewpY   397  QURTSl9pMHRjQ3QyLXZqZkw4TmVhanRRVDNraEJtcTBFeF...
# 402  7TavVZMewpY   398  QURTSl9pMHRZS2ZGMG8yY0xVTDZWd2psYkZNRzJrSFRNak...
# 403  7TavVZMewpY   399  QURTSl9pMVZ6cEY4aWN5Y1BXMmlHWElzSG1YUENyTWlkUl...
# 404  7TavVZMewpY   400  QURTSl9pM0plN1lGWUd3MTd0MmIwVnl4Mmp5WDNuR1Atan...
# 405  7TavVZMewpY   401                                               None
# 406  Fk2CB8yN0vk     1                                               None
# 407  DZGT939wTdI     1                                               None
# 408  Kpl79jNEVBI     1                                               None
# 409  HlVap90ndzo     1                                               None
#
#                    message
# 0    No available comments
# 1    No available comments
# 2    No available comments
# 3    No available comments
# 4    No available comments
# 5          success append!
# 6          success append!
# 7          success append!
# 8          success append!
# 9          success append!
# 10         success append!
# 11         success append!
# 12         success append!
# 13         success append!
# 14         success append!
# 15         success append!
# 16         success append!
# 17         success append!
# 18         success append!
# 19         success append!
# 20         success append!
# 21         success append!
# 22         success append!
# 23         success append!
# 24         success append!
# 25         success append!
# 26         success append!
# 27         success append!
# 28         success append!
# 29         success append!
# ..                     ...
# 380        success append!
# 12     Now, this looks familiar, where have I seen it...          1
# 13     "A king's time as ruler, rises and sets like t...          0
# 14               i am not ready for mufassas death again          0
# 15     If you watched this film, you know that the 19...          1
# 16     I loved this movie it’s not as good as the ori...          0
# 17     I kinda want to go back in time and try to con...          1
# 18     I'm EXTREMELY disappointed in you Disney. \nI'...          0
# 19     Nothing wrong with Lion King -- it's a great w...          0
# 20     They made a second remake of the Japanese anim...          0
# 21     African Elephant Trunks \nZebra African Attack...          0
# 22                                                  IMAX          0
# 23     Life Not Fairs\nMy Little Other\nSped Lion Fri...          1
# 24               I like this song I hope I enjoy it guys          1
# 25                                                  Cool          0
# 26     Lihat kemarahan ku kemarau dan di saat musim h...          0
# 27                                      Simba asli nyata          0
# 28                       hats next tom and jerry movie ?          0
# 29     Life’s Not Fair\nMy Little \nOther Speed Lion\...          0
# ...                                                  ...        ...
# 40001                                             *SCAR*          0
# 40002              IM SO READY OH MY GOD MY CHILDHOOD!!!         23
# 40003                          CAN'T WAIT OMG SO EXCITED          1
# 40004                                   Can't Wait!!!❤❤❤          0
# 40005                The animation looks super realistic        160
# 40006                     C’mon i an waiting for release          0
# 40007                                           Daaamnnn          0
# 40008                                         im excited          0
# 40009  I'm still thinking...is this animated or live-...         23
# 40010             OH MY GOD YES\nI GOT FRIGGIN CHILLLSSS          0
# 40011  OMG 😯 SIMBA I LOVE 💕 U NALA ⭐️⭐️⭐️ LIKE THIS I...          1
# 40012            Wow 33 views!! This trailer is AWESOME!         22
# 40013        MaaaaaaaaZieeeemmbaaaaawaaaa\n\n\nLETS GO!!          1
# 40014                                     Is this heaven          1
# 40015                                 The circle of life          0
# 40016                          Most awaited movie 😘😍😘👌👌👌          0
# 40017                                        from kerala          0
# 40018                                            BEYONCÉ          1
# 40019                                     WHO'S EXCITED!          1
# 40020                                           First ♥️          1
# 40021  Some people ignore Disney's notifications, but...        516
# 40022                           i’m already sobbing bye.          3
# 40023                         This movie going to be lit         16
# 40024    I was the first to like subscribe to my channel          0
# 40025                                     1st comment😊😊😊          1
# 40026                          I love 🦁 lion 1st comment          1
# 40027                                           1st like          1
# 40028                   Superb trailer vfx are fantastic          1
# 40029                                                  1          1
# 40030                                          Fuck this          0
#
#        commentsReplyCount
# 0                       0
# 1                       1
# 2                       0
# 3                       1
# 4                       0
# 5                       1
# 6                       0
# 7                       0
# 8                       0
# 9                       0
# 10                      0
# 11                      0
# 12                      1
# 13                      0
# 14                      0
# 15                      1
# 16                      0
# 17                      0
# 18                      2
# 19                      0
# 20                      1
# 21                      0
# 22                      0
# 23                      0
# 24                      0
# 25                      0
# 26                      0
# 27                      0
# 28                      0
# 29                      0
# ...                   ...
# 40001                   0
# 40002                   2
# 40003                   0
# 40004                   0
# 40005                   5
# 40006                   0
# 40007                   0
# 40008                   0
# 40009                  16
# 40010                   0
# 40011                   0
# 40012                   2
# 40013                   0
# 40014                   0
# 40015                   0
# 40016                   0
# 40017                   0
# 40018                   1
# 40019                   0
# 40020                   0
# 40021                   8
# 40022                   0
# 40023                   0
# 40024                   0
# 40025                   0
# 40026                   0
# 40027                   0
# 40028                   0
# 40029                   0
# 40030                   0
#
# [40031 rows x 6 columns]
